# %% [markdown]
# # 🌿 Plant Disease Detection System - EDA
#
# Welcome to the Exploratory Data Analysis (EDA) notebook for the **Plant Disease Detection System**. This notebook provides boilerplate code to explore the leaf dataset, inspect distributions, and visualize class samples.

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
import cv2

# Import custom modular helpers
from src.config import CLASS_NAMES, DATASET_PATH

# %%
print(f"Total Number of Classes: {len(CLASS_NAMES)}")
print(f"Dataset Directory: {DATASET_PATH}")

# %%
# Check dataset existence
if os.path.exists(DATASET_PATH):
    print("✅ Dataset folder found!")
else:
    print("❌ Dataset folder not found. Please refer to data/README.md for download instructions.")
